# %%
import warnings
warnings.simplefilter("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('ggplot')

# %%
#load data from csv file

df = pd.read_csv('c:/material/computer science knowledge/BitTiger/projects/bank/bank-full.csv',sep = ';') #get rid of the ;

# %%
# take a look at this data

df.head(5)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
#see the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
# age          45211 non-null int64
# job          45211 non-null object
# marital      45211 non-null object
# education    45211 non-null object
# default      45211 non-null object
# balance      45211 non-null int64
# housing      45211 non-null object
# loan         45211 non-null object
# contact      45211 non-null object
# day          45211 non-null int64
# month        45211 non-null object
# duration     45211 non-null int64
# campaign     45211 non-null int64
# pdays        45211 non-null int64
# previous     45211 non-null int64
# poutcome     45211 non-null object
# y            45211 non-null object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
# see the statistics of cantinious data
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# # visualizaiton of distribution of variables

# %%
# histogram

# Import library and dataset
import seaborn as sns
 
# Hist only
#sns.distplot( a=df["age"], hist=True, kde=False, rug=False )
#sns.plt.show()

# Vertical hist
#sns.distplot( df["sepal_length"] , color="skyblue", vertical=True)
#sns.plt.show()

 
# Hist + Rug + kernel density
#sns.distplot( a=df["age"], hist=True, kde=True, rug=True )
#sns.plt.show()
 
# To change parameters of rug
#sns.distplot( a=df["age"], rug=True,
#rug_kws={"color": "r", "alpha":0.3, "linewidth": 2, "height":0.2 }
#)
 
# To change parameters of density distribution
#sns.distplot( a=df["age"], kde=True,
#kde_kws={"color": "g", "alpha":0.3, "linewidth": 5, "shade":True }
#)
#sns.plt.show()

# %%
# box plot
# 1. one numerical variable only

#sns.boxplot( y=df["age"] )
#sns.plt.show()

# 2. one numerical variabl, several groups (categorical).

#sns.boxplot( x=df["marital"], y=df["age"] )
#sns.plt.show()

# 3. several numerical variables

#sns.boxplot(data=df.ix[:,11:14])
#sns.plt.show()

# %%
# density plot

#sns.kdeplot(df['age'],shade = True)
#sns.plt.show()

# Narrower bandwidth
#sns.kdeplot(df['age'], shade=True, bw=1, color="olive")

# plot of several variables
#p1=sns.kdeplot(df['campaign'], shade=True, bw = 10,color="r")
#p1=sns.kdeplot(df['day'], shade=True,bw = 10, color="b")
#p1=sns.kdeplot(df['age'], shade=True,bw = 10, color="y")

# %% [markdown]
# # visualization of correlation of variables

# %%
# 1. scattered plot (A Scatterplot displays the value of 2 sets of data on 2 dimensions)

# use the function regplot to make a scatterplot
#sns.regplot(x=df["age"], y=df["balance"])
#sns.plt.show()
 
# Without regression fit:
#sns.regplot(x=df["age"], y=df["balance"], fit_reg=False)
#sns.plt.show()

# Change shape of marker
#sns.regplot(x=df["age"], y=df["balance"], marker="+", fit_reg=False)
#sns.plt.show()

# More marker customization:
#sns.regplot(x=df["age"], y=df["balance"], fit_reg=False, scatter_kws={"color":"darkred","alpha":0.3,"s":100} )
#sns.plt.show()

# Use the 'hue' argument to provide a factor variable
#sns.lmplot( x="balance", y="age", data=df, fit_reg=False, hue='marital', legend=False,markers=["o", "x", "1"]) 
# Move the legend to an empty part of the plot
#plt.legend(loc='lower right') 
#sns.plt.show()


# 2. heatmap A common task is to check if some variables are correlated. You can easily calculate the correlation 
# between each pair of variable, and plot this as a heatmap. This lets you discover which variable are related one 
#each other

# Calculate correlation between each pair of variable
#df_num = df[['age','balance','day','duration','campaign','pdays','previous']]
#corr_matrix=df_num.corr() 
# plot it
#sns.heatmap(corr_matrix, cmap='PuOr')
#sns.plt.show()


# correlation matrix (awesome for exploratory analysis: it allows to quickly observe the relationship between every 
#variable of your matrix)

# Basic correlogram
#sns.pairplot(df)
#sns.plt.show()

# with regression
#sns.pairplot(df, kind="reg")
#plt.show()
 
# without regression
#sns.pairplot(df, kind="scatter")
#plot.show()

# left
#sns.pairplot(df, kind="scatter", hue="marital", markers=["o", "s", "D"], palette="Set2")
#plt.show()


# 3. barplot (shows the relationship between a numerical variable and a categorical variable.)
# Create bars
#plt.bar(df['marital'].value_counts(), df['age']) 
# Create names on the x-axis
#plt.xticks(df['marital'].value_counts(), bars) 
# Show graphic
#plt.show()

df['marital'].value_counts().plot(kind = "bar",alpha = 0.5)

# %% [markdown]
# # handle categorical data

# %%
cat_features = ['job','marital','education','default','housing','loan','contact','month','poutcome']
df = pd.get_dummies(df,columns = cat_features)

# %%
df.columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous',
#        'y', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
#        'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
#        'job_services', 'job_student', 'job_technician', 'job_unemployed',
#        'job_unknown', 'marital_divorced', 'marital_married', 'marital_single',
#        'education_primary', 'education_secondary', 'education_tertiary',
#        'education_unknown', 'default_no', 'default_yes', 'housing_no',
#        'housing_yes', 'loan_no', 'loan_yes', 'contact_cellular',
#        'contact_telephone', 'contact_unknown', 'month_apr', 'month_aug',
#        'month_dec', 'month_feb', 'month_jan', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'poutcome_failure', 'poutcome_other', 'poutcome_success',
#        'poutcome_unknown'],
#       dtype='object')

# %% [markdown]
# # get target variable

# %%
df['y'] = (df['y'] == 'yes').astype(int)

# %% [markdown]
# # Build Logistic Regretion Model

# %%
#define features and target
selected_features = list(df.columns.values)
target = 'y'
selected_features.remove(target)

X = df[selected_features].values
y = df[target].values

X.shape
# Out:
# (45211, 51)

# %%
y
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
#split train test dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 0)

# %% [markdown]
# # Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

#initializing model by providing parameters
lgm = LogisticRegression(C=1.0, penalty = 'l2')

#fit the model by providing x and y from the training set
lgm.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# make prediction on the training data
y_train_pred = lgm.predict(X_train)
p_train_pred = lgm.predict_proba(X_train)[:,1]


#make prediction on testing data
y_test_pred = lgm.predict(X_test)
p_test_pred = lgm.predict_proba(X_test)[:,1]

# %%
# calculate the matrix scores for the model
#import metrics function from sklearn model

from sklearn.metrics import precision_score,accuracy_score,recall_score,f1_score,roc_auc_score
import pandas as pd

# helper method to print metric scores
def get_performance_metrics(y_train,y_train_pred,y_test,y_test_pred,threshold = 0.5):
    metric_names = ['AUC','Accuracy','Precision','Recall','f1-score']
    metric_values_train = [roc_auc_score(y_train, y_train_pred),
                    accuracy_score(y_train, y_train_pred>threshold),
                    precision_score(y_train, y_train_pred>threshold),
                    recall_score(y_train, y_train_pred>threshold),
                    f1_score(y_train, y_train_pred>threshold)
                   ]
    metric_values_test = [roc_auc_score(y_test, y_test_pred),
                    accuracy_score(y_test, y_test_pred>threshold),
                    precision_score(y_test, y_test_pred>threshold),
                    recall_score(y_test, y_test_pred>threshold),
                    f1_score(y_test, y_test_pred>threshold)
                   ]
    all_metrics = pd.DataFrame({'metrics':metric_names,
                                'train':metric_values_train,
                                'test':metric_values_test},columns=['metrics','train','test']).set_index('metrics')
    print(all_metrics)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,auc

def plot_roc_curve(y_train, y_train_pred, y_test, y_test_pred):
    roc_auc_train = roc_auc_score(y_train, y_train_pred)
    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_pred)

    roc_auc_test = roc_auc_score(y_test, y_test_pred)
    fpr_test, tpr_test, _ = roc_curve(y_test, y_test_pred)
    plt.figure()
    lw = 2
    plt.plot(fpr_train, tpr_train, color='green',
             lw=lw, label='ROC Train (AUC = %0.4f)' % roc_auc_train)
    plt.plot(fpr_test, tpr_test, color='darkorange',
             lw=lw, label='ROC Test (AUC = %0.4f)' % roc_auc_test)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
# print model result

get_performance_metrics(y_train, p_train_pred, y_test, p_test_pred)
plot_roc_curve(y_train, p_train_pred, y_test, p_test_pred)
# Out:
#               train      test
# metrics
# AUC        0.909539  0.895982
# Accuracy   0.902621  0.899038
# Precision  0.656444  0.625418
# Recall     0.349503  0.351834
# f1-score   0.456146  0.450331

# %% [markdown]
# # Estimated coefficients

# %%
df_coeffs = pd.DataFrame(list(zip(selected_features, lgm.coef_.flatten()))).sort_values(by = [1],ascending = False)
df_coeffs.columns = ['features','coeff']
df_coeffs
# Out:
#                features     coeff
# 49     poutcome_success  1.579434
# 42            month_mar  1.297766
# 45            month_oct  0.813007
# 46            month_sep  0.736503
# 12          job_retired  0.432707
# 32     contact_cellular  0.394592
# 41            month_jun  0.386132
# 15          job_student  0.353801
# 37            month_dec  0.322607
# 33    contact_telephone  0.182634
# 7            job_admin.  0.049343
# 6              previous  0.008318
# 28           housing_no  0.008261
# 24   education_tertiary  0.008238
# 2                   day  0.005401
# 3              duration  0.004219
# 1               balance  0.000014
# 5                 pdays -0.000334
# 0                   age -0.002967
# 17       job_unemployed -0.035186
# 35            month_apr -0.054596
# 18          job_unknown -0.056482
# 4              campaign -0.087929
# 16       job_technician -0.098754
# 11       job_management -0.099404
# 25    education_unknown -0.121293
# ...

# %%
ax = df_coeffs.plot.barh()
t = np.arange(X.shape[1])
ax.set_yticks(t)
ax.set_yticklabels(df_coeffs['features'])
plt.gcf().set_size_inches(6, 12)
plt.show()

# %% [markdown]
# # Bagging (single tree)

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth = 20,min_samples_leaf = 10)

#fit the model with training data set
clf.fit(X_train,y_train)

# make prediction on training data
x_train_pred = clf.predict(X_train)
p_train_pred = clf.predict_proba(X_train)[:,1]

# make prediction on test data
x_test_pred = clf.predict(X_test)
p_test_pred = clf.predict_proba(X_test)[:,1]

#print model result
get_performance_metrics(y_train,p_train_pred,y_test,p_test_pred)
plot_roc_curve(y_train,p_train_pred,y_test,p_test_pred)
# Out:
#               train      test
# metrics
# AUC        0.965730  0.859733
# Accuracy   0.933754  0.886100
# Precision  0.767544  0.517954
# Recall     0.621155  0.447789
# f1-score   0.686634  0.480323

# %% [markdown]
# # Bagged trees

# %%
# define a function to perfoem train,test, and get model performance
def train_test_model(clf,X_train,y_train,X_test,y_test):
    
    #fit a model by providing x and y from training dataset
    clf.fit(X_train,y_train)
    
    #make prediction on the training data
    y_train_pred = clf.predict(X_train)
    p_train_pred = clf.predict_proba(X_train)[:,1]
    
    #make prediction on the test data
    y_test_pred = clf.predict(X_test)
    p_test_pred = clf.predict_proba(X_test)[:,1]
    
    #print model result
    get_performance_metrics(y_train,p_train_pred,y_test,p_test_pred)
    plot_roc_curve(y_train,p_train_pred,y_test,p_test_pred)

# %%
from sklearn.ensemble import BaggingClassifier

base_classifier = DecisionTreeClassifier(max_depth = 20, min_samples_leaf = 10)

parameters = {
               "base_estimator":base_classifier,
               "n_estimators":50,
               "n_jobs": -1  # how to use this parameter and why choose this 3 parameter
}

clf = BaggingClassifier(**parameters)

#train test mosel

train_test_model(clf,X_train,y_train,X_test,y_test)
# Out:
#               train      test
# metrics
# AUC        0.971611  0.927190
# Accuracy   0.941495  0.902577
# Precision  0.826020  0.608076
# Recall     0.632513  0.481656
# f1-score   0.716430  0.537533

# %% [markdown]
# # Single KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

parameters = { 
               #"weights":'distance',
               'n_neighbors':3,
               'leaf_size':10
}

base_classifier = KNeighborsClassifier(**parameters) # what does ## mean?
clf = base_classifier

#train test model
train_test_model(clf,X_train,y_train,X_test,y_test)
# Out:
#               train      test
# metrics
# AUC        0.956968  0.728772
# Accuracy   0.924159  0.871945
# Precision  0.760267  0.435021
# Recall     0.512541  0.299153
# f1-score   0.612297  0.354515

# %% [markdown]
# # Bagged KNN

# %%
from sklearn.ensemble import BaggingClassifier

#choose some parameter combination to try
parameters = {
               "base_estimator":base_classifier,
               "n_estimators":50,
               'n_jobs':-1
              }

clf = BaggingClassifier(**parameters)

#train_test_model
train_test_model(clf,X_train,y_train,X_test,y_test)
# Out:
#               train      test
# metrics
# AUC        0.977587  0.780155
# Accuracy   0.931348  0.875816
# Precision  0.827262  0.455621
# Recall     0.521297  0.289746
# f1-score   0.639570  0.354227

# %% [markdown]
# # Random Forest
# #randomly select subset from the features to determin spliting point. This would reduce the correlatin between
# #trees. Bagging improves variance by averaging/majority selection of outcome from multiple fully grown trees on
# #variants of training set. It uses Bootstrap with replacement to generate multiple training sets.

# %%
from sklearn.ensemble import RandomForestClassifier

parameters = {
              'n_estimators':50,
              'max_features':'auto',
              'criterion':'gini',
              'max_depth':20,
              'min_samples_split':2,
              'min_samples_leaf':20,
              'random_state':0,
              'n_jobs':-1 
            }
clt = RandomForestClassifier(**parameters)

#fit model with training dataset
clt.fit(X_train,y_train)

#get training testing performance
train_test_model(clf,X_train,y_train,X_test,y_test)
# Out:
#               train      test
# metrics
# AUC        0.977550  0.780016
# Accuracy   0.930546  0.873936
# Precision  0.823885  0.442105
# Recall     0.515854  0.276576
# f1-score   0.634459  0.340278

# %%
# Gradient boosting tree
# gradient boosting tree create a series of tree models and focuse on the mistakes the previouse tree model has made
# and select those mistakes as features in next tree model, so by adding more and more trees the mistakes getting 
# less and the performance geting better.

# %%
#good: often best performance/ only requires modest memory and CPU, is fast/doesn't require careful normalization of features
      #to perform well/ like decision tree, hendle mixture types of features.(continous, categorical)
#bad: hard to interprete./requires careful tuning of learning rate and other parameters./ the training process requires significant
      # computation./ not good at dealing with high dimensional sparse features like text classification prblem.

# %%
# works well with non-linear data?
#given the current model, we fit a decision tree to the residules from the model.?
# what is the depth of the tree and the split point of the tree?

# %%
from sklearn.ensemble import GradientBoostingClassifier

#key parameters:
parameters = {'n_estimators': 50,        # the number of trees you want to train
              'learning_rate':0.2,       # how fast you wanna each tree to learn. the higher the learning rate, the complex th model
              'max_depth':5,             # usually n_estimator and learning rate should be tuned together, since low learning rate
              'random_state':42          # asks for more trees to learn.
}                                        # max_depth used to controling the depth of individual tree and also can affect the model  
                                         # model complexity. usually (3-5)
    
clf = GradientBoostingClassifier(**parameters)

#train test model
train_test_model(clf,X_train,y_train,X_test,y_test)
# Out:
#               train      test
# metrics
# AUC        0.954265  0.927638
# Accuracy   0.929938  0.902577
# Precision  0.770633  0.611520
# Recall     0.570043  0.469426
# f1-score   0.655332  0.531134

# %%
# Neural Network

# %%
from sklearn.neural_network import MLPClassifier

parameters = {
              'solver':'adam',
              'activation':'relu',
              'alpha': 1e-6,  #increase aloha -> increase penalty
              'hidden_layer_sizes':(10,10,10),
              'learning_rate':'adaptive',
              'random_state':1
}

clf = MLPClassifier(**parameters)

train_test_model(clf,X_train,y_train,X_test,y_test)
# Out:
#               train      test
# metrics
# AUC        0.913040  0.901399
# Accuracy   0.899663  0.888643
# Precision  0.593544  0.533573
# Recall     0.448178  0.418627
# f1-score   0.510719  0.469162

# %%
#SVM

# %%
from sklearn.svm import LinearSVC

clf = LinearSVC()

clf.fit(X_train,y_train)

#there is no prediction probability for linearSVC

p_train_pred = clf.predict(X_train)

p_test_pred = clf.predict(X_test)

#print model result:
get_performance_metrics(y_train,p_train_pred,y_test,p_test_pred)
plot_roc_curve(y_train,p_train_pred,y_test,p_test_pred)
# Out:
#               train      test
# metrics
# AUC        0.715770  0.724632
# Accuracy   0.698877  0.705407
# Precision  0.241687  0.249452
# Recall     0.737814  0.749765
# f1-score   0.364103  0.374354

# %%
#non-linear SVM

# %%
from sklearn.svm import SVC

parameters = {
               'probability':True,
               'max_iter':2000
}

clf = SVC(**parameters)

train_test_model(clf,X_train,y_train,X_test,y_test)
# Out:
#               train      test
# metrics
# AUC        0.893394  0.654227
# Accuracy   0.932592  0.882340
# Precision  1.000000  0.000000
# Recall     0.423095  0.000000
# f1-score   0.594613  0.000000

# %%
#Hyper parameter tuning

# %%
from sklearn.metrics import make_scorer, roc_auc_score, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
clf = RandomForestClassifier()

param_grid = {
              'n_estimators':[100,200],
              'max_features':['auto'],
              'criterion':['gini'],
              'max_depth':[15,20,25],
              'min_samples_split':[2],
              'min_samples_leaf':[2,10,20],
              'n_jobs':[-1]
}

# type of scoring to compare parameter combinations
acc_scorer = make_scorer(roc_auc_score)

# run grid search
grid_obj = GridSearchCV(clf,param_grid,cv=5,scoring = acc_scorer)
grid_obj = grid_obj.fit(X_train,y_train)

# set clf to the best combination of parameters
clf = grid_obj.best_estimator_

#fit the best algorithm to the data
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=25, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
train_test_model(clf,X_train,y_train,X_test,y_test)
# Out:
#               train      test
# metrics
# AUC        0.995739  0.928867
# Accuracy   0.971273  0.901802
# Precision  0.985084  0.633588
# Recall     0.765736  0.390405
# f1-score   0.861670  0.483120
